# %%
#!/usr/bin/env python
# coding: utf-8

import requests
import json
import os
import urllib.request
import pandas as pd
import re
#import cx_Oracle
from datetime import datetime, timedelta

folder_path = os.path.abspath("./")
PGNfolder = folder_path + "/PGN"

#print(PGNfolder)

def get_PGN(player, pgn = False):
    
    if pgn == False:
        pgn = ''
        
    elif pgn != False:
        pgn = '/pgn'
    
    #Gets the pgn files from the chesscom api and saves it locally by month file
    pgn_archives = requests.get('https://api.chess.com/pub/player/'+player.lower()+'/games/archives')
    #garantees that the player will always be lowercase, in case the user writes it differently
    print("Solving %s online data..." % player)
    try:
        #print(json.loads(pgn_archives.content)["archives"])
        skip_refiller = True #this variable helps to check if I have to remove the last month and redownload it
        if not os.path.exists(PGNfolder):
            #check if the main /pgn folder exist, if not it creates
            os.makedirs(PGNfolder)
            
        for month_url in json.loads(pgn_archives.content)["archives"]:
            #goes through all the archives and check each month
            user_folder = PGNfolder + '/' + month_url.split("/")[-4]
            folderpath = user_folder + "/" + month_url.split("/")[-2] + "-" + month_url.split("/")[-1]

            if not os.path.exists(user_folder):
                #checks if the name folder existis, if not it will create
                os.makedirs(user_folder)
            
            if not os.path.exists(folderpath+".txt"):
                #check if the month file exists, if not it will create
                urllib.request.urlretrieve(month_url + pgn, folderpath+".txt")
                print("New folder found %s" % folderpath)
                skip_refiller = False #it's a completely new month, it won't redownload it
        
        if skip_refiller:
            os.remove(folderpath + ".txt")
            urllib.request.urlretrieve(month_url + pgn, folderpath+".txt")
            print("Refilling folder %s" % folderpath)
        
        print("%s data solved." % player)
        return(True)
    except KeyError: #if the given player doesn't have an archive nor exists, it'll return as player not found and boolean False
        print("player not found")
        return(False)
    
def extract_data(filepath):
    #Loads the PGN files from the local folders
    #print("Reading PGN")
    with open(filepath) as f:
        #print(f.readlines())
        return f.readlines()
    
def data_delimiter(data):
    #Returns two lists: One with the beginnings and another with the endings of each game in a data list
    start = []
    end = []
    
    for i,j in enumerate(data):

        if j.startswith("[Event"):
            start.append(i)
            if i != 0:
                end.append(i - 2)

    end.append(len(data))

    return(start, end)

def PGNExtract(data):
    s = data.split(" ")
    
    game = "1."
    
    for i, j in enumerate(s):
        
        if j != "1.":
            if ("1-0" in j) or ("0-1" in j) or ("1/2-1/2" in j):
                j = j[:-1]
                game = game + " " + j

            elif ("{" not in j) and ("}" not in j) and ("..." not in j):
                game = game + " " + j            
            
    return(game)

def pieceMoveCounter(moves, playerColor, timeControl_is, id_):
    #This function counts how many time I moved each piece
    s = moves.split(" ")
    
    pieceMoves[id_] = {"Q" : 0,
                       "N" : 0,
                       "R" : 0,
                       "K" : 0,
                       "B" : 0,
                       "p" : 0,
                       "O_O" : 0,
                       "O_O_O" : 0,
                       "x" : 0,
                       "check" : 0}
    
    if playerColor == "White":
        somador = 1
        
    elif playerColor == "Black":
        somador = 2
    
    for i, move in enumerate(s):
        if "." in move:
            if ("1-0" in s[i + somador]) or ("1/2-1/2" in s[i+somador]) or ("0-1" in s[i+somador]):
                break
            else:
                #print(s[i+somador])
                if "+" in s[i+somador]:
                    pieceMoves[id_]["check"] += 1

                if "x" in s[i+somador]:
                    pieceMoves[id_]["x"] += 1

                if "Q" in s[i+somador]:
                    pieceMoves[id_]["Q"] += 1

                elif "N" in s[i+somador]:
                    pieceMoves[id_]["N"] += 1

                elif "R" in s[i+somador]:
                    pieceMoves[id_]["R"] += 1

                elif "K" in s[i+somador]:
                    pieceMoves[id_]["K"] += 1

                elif "B" in s[i+somador]:
                    pieceMoves[id_]["B"] += 1

                elif "O-O-O" in s[i+somador]:
                    pieceMoves[id_]["O_O_O"] += 1

                elif "O-O" in s[i+somador]:
                    pieceMoves[id_]["O_O"] += 1

                else:
                    pieceMoves[id_]["p"] += 1

def transform_data(data, start, end, player, pgn = True):
    #print(data)
    
    pattern = "\"(.*?)\"" #pattern for regular expression delimiting data between ""
    allGames = []
    for i in range(0, len(start)):
        
        inGame = []
        #game = data[start[i]].split('\n')
        game = data[start[i]:end[i]] #game delimitation  
        if game[10].startswith("[ECOUrl"):
            whitePlayer = re.search(pattern, game[4]).group(1)
            if whitePlayer == player: #se o player estiver de brancas
                inGame.append(whitePlayer) #append player
                inGame.append("White") #append player color
                inGame.append(re.search(pattern, game[5]).group(1)) #append black player

            else:
                inGame.append(re.search(pattern, game[5]).group(1)) #append black player
                inGame.append("Black") #append player color
                inGame.append(whitePlayer) #append opponent

            winner = re.search(pattern, game[16]).group(1) #get winner and winning reason
            winner = winner.split(" ")

            if winner[0] == player:
                inGame.append('Winner') #indicates that the player won
                inGame.append(winner[-1]) #winning reason

            elif winner[0] == 'Game':
                inGame.append('Draw') #indicates that the player drew
                inGame.append(winner[-1]) #winning reason

            else:
                inGame.append('Loser') #indicates that the player lost
                inGame.append(winner[-1]) #winning reason

            if whitePlayer == player: #se o player estiver de brancas
                inGame.append(re.search(pattern, game[13]).group(1)) #player ELO
                inGame.append(re.search(pattern, game[14]).group(1)) #opponent ELO

            else: #Se o jogador estiver de pretas
                inGame.append(re.search(pattern, game[14]).group(1)) #Player ELO
                inGame.append(re.search(pattern, game[13]).group(1)) #Opponent ELO

            inGame.append(re.search(pattern, game[15]).group(1)) #Defines time control
            print(game)
            dateObject = datetime.strptime(re.search(pattern, game[2]).group(1), "%Y.%m.%d") #Defines date in UTC
            time_utc = re.search(pattern, game[12]).group(1) #get the time in UTC

            #Here converts time UTC to UTC-3, since I'm brazilian
            utc_dt = dateObject.strftime("%d/%m/%Y") + " " + time_utc
            utc_dt = datetime.strptime(utc_dt, "%d/%m/%Y %H:%M:%S")
            utc_br = utc_dt - timedelta(hours=3)

            inGame.append(utc_br.strftime("%d/%m/%Y")) #Set date as dd/mm/YYYY

            inGame.append(utc_br.strftime("%H:%M:%S")) #insert time into the list

            pattern2 = "\"https://www.chess.com/openings/(.*?)\"" #gets the link our of the equation
            substring = re.search(pattern2, game[10]).group(1) #same
            
            pattern2 = "(.*?)\."
            #substring2 = re.search(pattern, substring).group(1)
            try: #this will try to remove the ...nf3 stuff
                substring = re.search(pattern2, substring).group(1)
                substring = substring.replace("-1", "")
                substring = substring.replace("-2", "")
                substring = substring.replace("-3", "")
                substring = substring.replace("-4", "")
                substring = substring.replace("-5", "")
                substring = substring.replace("-6", "")
            except: #if there's no stuff like this, continues normally
                substring = substring.replace("-1", "")
                substring = substring.replace("-2", "")
                substring = substring.replace("-3", "")
                substring = substring.replace("-4", "")
                substring = substring.replace("-5", "")
                substring = substring.replace("-6", "")
                
                        
            if "Opening" in substring:
                pattern2 = "(.*?)-Opening" #gets the link our of the equation
                substring = re.search(pattern2, substring).group(1) + "-Opening"#same
                #print(substring)
                
            if "Defense" in substring:
                pattern2 = "(.*?)-Defense" #gets the link our of the equation
                substring = re.search(pattern2, substring).group(1) + "-Defense"#same
                #print(substring)
                
            if "Game" in substring:
                pattern2 = "(.*?)-Game" #gets the link our of the equation
                substring = re.search(pattern2, substring).group(1) + "-Game"#same
                #print(substring)
            
            if "Attack" in substring:
                pattern2 = "(.*?)-Attack" #gets the link our of the equation
                substring = re.search(pattern2, substring).group(1) + "-Attack"#same
                #print(substring)
            
            #print(substring)
            inGame.append(substring)
                
            gamePGN = PGNExtract(game[-1])
                
            inGame.append(gamePGN) #pgn transformed into a string
            
            try: #the id from the game link is the id in the database
                pattern2 = "\"https://www.chess.com/game/live/(.*?)\"" #gets the link our of the equation
                inGame.append(re.search(pattern2, game[20]).group(1)) #same
            except:
                pattern2 = "\"https://www.chess.com/game/daily/(.*?)\"" #gets the link our of the equation
                inGame.append(re.search(pattern2, game[20]).group(1)) #same
            
            
            #Here it goes to the function to count how many times I moved each piece
            #pieceMoveCounter(gamePGN, inGame[1], inGame[-6], inGame[-1])

            #print("---")
            #print(inGame)
            allGames.append(inGame)

            
    return(allGames)
     
    
#Get some information to print later by a given dataframe
def get_print_info(dataFrame):
    
    #Total games played
    total_games = dataFrame.shape[0]
    
    #How many games tha player won
    games_won = dataFrame[dataFrame.result == 'Winner'].shape[0]
    #How many games tha player won
    games_lost = dataFrame[dataFrame.result == 'Loser'].shape[0]
    #How many games tha player won
    games_drew = dataFrame[dataFrame.result == 'Draw'].shape[0]
    
    return(games_won, games_lost, games_drew, total_games)

#Returns a percentage. To recude verbosity
def percent(numerator, denominator):
    return(round(((numerator / denominator)*100), 2))

#returns a dataframe with only rows where the player used a specific color and the most played opening
def get_color_opening(df_in, color):
    df_Games = df_in[df_in.playerColor == color] #Gets the chosen color
    df_Games = df_Games[df_Games.opening == df_Games.opening.mode()[0]] #Returns the most played opening in that color
    return(df_Games)

#Print some data from a given dataframe
def color_analysis_print(df_color):
    #Gets the player color
    color = df_color.playerColor.iloc[0]
    #get's some information to print
    games_won, games_lost, games_drew, total_games = get_print_info(df_color)

    percent_win = percent(games_won, total_games)
    percent_draw = percent(games_drew, total_games)
    percent_lost = percent(games_lost, total_games)
    #Print the information
    print("    %s: %s, with %s%% winrate" % (color, df_color.opening.mode()[0], percent_win))
    
    
class chess():
    
    def __init__(self):
        self.soup = ''
        
    def extract(self, player):
        dfColumns = ["player", "playerColor", "opponent", "result", "winningReason", "playerElo", "oponentElo", "timeControl", 'date', 'time', 'opening', 'pgn', 'id']
        global pieceMoves
        pieceMoves = {}
        playerExists = get_PGN(player) #tries to download player PGN data
        if playerExists: #If the player exists, then:        

            #global df
            self.df = pd.DataFrame(columns=dfColumns)
            #pieceMoves_df = pd.DataFrame(columns=pieceMovesColumns)
            with os.scandir(PGNfolder + "/" + player.lower()) as folders: #goes through all the player month files
                print("Creating dataframe")
                for file in folders:
                    #print(file)
                    #global data
                    data1 = extract_data(file) #load each month file into the memory
                    data = []
                    for i in range(len(json.loads(data1[0])['games'])):
                        data.append(json.loads(data1[0])['games'][i]['pgn'].split('\n'))
                    
                    start, end = data_delimiter(data) #defines the limits of each data part
                    
                    #print(data[start[k]:end[k]])

                    allGames = transform_data(data, start, end, player)
                    #break
                    df2 = pd.DataFrame(data=allGames, columns=dfColumns)
                    self.df = self.df.append(df2, ignore_index=True)

        else: #If the player does not exist, it stops
            print("There's no %s data on chess.com" % player)

        print("Done")   
        #return(self.df)
    def stats(self):
        print("--------------------------------------------------")
        player = self.df.player.iloc[0]
        print("      Chess analysis for %s " % (player))
        print("--------------------------------------------------")

        games_won, games_lost, games_drew, total_games = get_print_info(self.df)

        percent_win = percent(games_won, total_games)
        percent_draw = percent(games_drew, total_games)
        percent_lost = percent(games_lost, total_games)

        print("\n%s played %s games\n\n  Wins %s (%s%%)\n  Draws %s (%s%%)\n  Loses %s (%s%%)" % (player, total_games, games_won, percent_win \
                                                                            , games_drew, percent_draw, games_lost, percent_lost))

        #########################################################################
        print('\nMost played opening as')

        df_whiteGames = get_color_opening(self.df, 'White')
        color_analysis_print(df_whiteGames)
        del df_whiteGames

        df_blackGames = get_color_opening(self.df, 'Black')
        color_analysis_print(df_blackGames)
        del df_blackGames

        #########################################################################

        #The opponent the player most played agaisnt
        df_mostPlayed = self.df[self.df.opponent == self.df.opponent.mode()[0]]
        print('\n-----------------\n\nArch-enemy: %s\n' % (df_mostPlayed.opponent.iloc[0]))

        #Some info to print
        games_won, games_lost, games_drew, total_games = get_print_info(df_mostPlayed)

        percent_win = percent(games_won, total_games)
        percent_draw = percent(games_drew, total_games)
        percent_lost = percent(games_lost, total_games)

        print('%s won %s games out of %s against %s\n' % \
              (player, games_won, total_games, df_mostPlayed.opponent.iloc[0]))

        del df_mostPlayed
        print('  Wins: %s%%\n  Draws: %s%%\n  Loses: %s%%\n' % (percent_win, percent_draw, percent_lost))


def main():
    print('teste')

if __name__ == "__main__":
    print("-")
    #main("GMKrikor")
# Out:
# -

# %%
with os.scandir('PGN' + "/" + 'hallsand'.lower()) as folders: #goes through all the player month files
    print("Creating dataframe")
    for file in folders:

        data1 = extract_data(file) #load each month file into the memory
        data = []
        for i in range(len(json.loads(data1[0])['games'])):
            data.append(json.loads(data1[0])['games'][i]['pgn'])

        print(data)
# Out:
# Creating dataframe
# ['[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Date "2020.03.01"]\n[Round "-"]\n[White "Danielhost19"]\n[Black "Hallsand"]\n[Result "1-0"]\n[CurrentPosition "r1bqkb1r/ppp1pppp/2n2n2/3pN3/3P4/4P3/PPP2PPP/RNBQKB1R b KQkq - 4 4"]\n[Timezone "UTC"]\n[ECO "D04"]\n[ECOUrl "https://www.chess.com/openings/Colle-System"]\n[UTCDate "2020.03.01"]\n[UTCTime "18:27:42"]\n[WhiteElo "800"]\n[BlackElo "1081"]\n[TimeControl "1/86400"]\n[Termination "Danielhost19 won on time"]\n[StartTime "18:27:42"]\n[EndDate "2020.03.04"]\n[EndTime "00:00:04"]\n[Link "https://www.chess.com/game/daily/253102534"]\n\n1. d4 {[%clk 6:34:19]} 1... d5 {[%clk 23:59:42]} 2. e3 {[%clk 22:15:05]} 2... Nf6 {[%clk 23:28:10]} 3. Nf3 {[%clk 23:44:54]} 3... Nc6 {[%clk 23:54:11]} 4. Ne5 {[%clk 14:32:28]} 1-0\n', '[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Date "2020.03.21"]\n[Round "-"]\n[White "Hallsand"]\n[Black "Osvaldo937"]\n[Result "0-1"]\n[CurrentPosition "rn1qkb1r/pp2pppp/3p1n2/2p5/3PP1b1/2N2N2/PPP2PPP/R1BQKB1R w KQkq - 4 5"]\n[Timezone "UTC"]\n[ECO "B07"]\n[ECOUrl "https://www.chess.com/openings/Pirc-Defense-2.d4"]\n[UTCDate "2020.03.21"]\n[UTCTime "17:34:25"]\n[WhiteElo "1081"]\n[BlackElo "1000"]\n[TimeControl "1/86400"]\n[Termination "Osvaldo937 won on time"]\n[StartTime "17:34:25"]\n[EndDate "2020.03.23"]\n[EndTime "23:00:03"]\n[Link "https://www.chess.com/game/daily/255393656"]\n\n1. e4 {[%clk 23:58:26]} 1... d6 {[%clk 23:54:32]} 2. d4 {[%clk 23:42:09]} 2... c5 {[%clk 23:35:55]} 3. Nf3 {[%clk 21:23:44]} 3... Nf6 {[%clk 1:39:40]} 4. Nc3 {[%clk 20:35:32]} 4... Bg4 {[%clk 23:44:43]} 0-1\n', '[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Date "2020.03.19"]\n[Round "-"]\n[White "Danielhost19"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "5rk1/pp3ppp/2n5/8/1P6/1B1bn1BN/1P2r1PP/R3K2R w - - 1 22"]\n[Timezone "UTC"]\n[ECO "D00"]\n[ECOUrl "https://www.chess.com/openings/Queens-Pawn-Opening-Blackmar-Gambit-2...dxe4"]\n[UTCDate "2020.03.19"]\n[UTCTime "13:29:07"]\n[WhiteElo "800"]\n[BlackElo "1081"]\n[TimeControl "1/86400"]\n[Termination "Hallsand won by checkmate"]\n[StartTime "13:29:07"]\n[EndDate "2020.03.25"]\n[EndTime "13:44:23"]\n[Link "https://www.chess.com/game/daily/255102942"]\n\n1. d4 {[%clk 23:58:53]} 1... d5 {[%clk 23:59:20]} 2. e4 {[%clk 1:38:33]} 2... dxe4 {[%clk 23:58:59]} 3. Bb5+ {[%clk 9:55:20]} 3... c6 {[%clk 23:58:56]} 4. Ba4 {[%clk 23:59:44]} 4... Nf6 {[%clk 9:08:16]} 5. c4 {[%clk 23:32:01]} 5... Be6 {[%clk 23:49:00]} 6. d5 {[%clk 23:54:47]} 6... Bf5 {[%clk 23:36:20]} 7. dxc6 {[%clk 23:46:18]} 7... Nxc6 {[%clk 23:45:53]} 8. Nc3 {[%clk 23:23:06]} 8... Qxd1+ {[%clk 5:42:58]} 9. Kxd1 {[%clk 4:57:39]} 9... e6 {[%clk 7:49:17]} 10. Bf4 {[%clk 23:45:47]} 10... Bc5 {[%clk 12:01:11]} 11. Bg3 {[%clk 22:36:58]} 11... O-O {[%clk 18:21:34]} 12. Nh3 {[%clk 23:51:45]} 12... Rad8+ {[%clk 23:59:14]} 13. Nd5 {[%clk 23:52:49]} 13... exd5 {[%clk 23:58:30]} 14. cxd5 {[%clk 22:20:40]} 14... Rxd5+ {[%clk 23:59:34]} 15. Ke1 {[%clk 23:50:11]} 15... Ng4 {[%clk 23:46:12]} 16. Bb3 {[%clk 23:57:07]} 16... Bb4+ {[%clk 23:59:20]} 17. Ke2 {[%clk 23:48:08]} 17... Rd2+ {[%clk 23:59:05]} 18. Ke1 {[%clk 22:51:42]} 18... e3 {[%clk 19:26:21]} 19. fxe3 {[%clk 15:36:49]} 19... Nxe3 {[%clk 23:59:11]} 20. a3 {[%clk 23:49:17]} 20... Bd3 {[%clk 23:54:47]} 21. axb4 {[%clk 23:04:31]} 21... Re2# {[%clk 23:58:41]} 0-1\n', '[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Date "2020.03.24"]\n[Round "-"]\n[White "Osvaldo937"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBNR w KQkq e6 0 2"]\n[Timezone "UTC"]\n[ECO "C20"]\n[ECOUrl "https://www.chess.com/openings/Kings-Pawn-Opening-1...e5"]\n[UTCDate "2020.03.24"]\n[UTCTime "23:45:41"]\n[WhiteElo "1000"]\n[BlackElo "1081"]\n[TimeControl "1/86400"]\n[Termination "Hallsand won on time"]\n[StartTime "23:45:41"]\n[EndDate "2020.03.26"]\n[EndTime "04:10:02"]\n[Link "https://www.chess.com/game/daily/255870284"]\n\n1. e4 {[%clk 23:58:41]} 1... e5 {[%clk 19:39:15]} 0-1\n', '[Event "Let\'s Play!"]\n[Site  ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.01.16"]\n[Round "-"]\n[White "Hallsand"]\n[Black "muratmerttaykan"]\n[Result "0-1"]\n[CurrentPosition "r2qk2r/ppbn2pp/2p1n3/3p3b/B7/2P2N1P/PP1N1PP1/R2Q2K1 w kq -"]\n[Timezone "UTC"]\n[ECO "C43"]\n[ECOUrl "https://www.chess.com/openings/Petrovs-Defense-Steinitz-Attack-3...d5"]\n[UTCDate "2020.01.16"]\n[UTCTime "14:12:25"]\n[WhiteElo "662"]\n[BlackElo "675"]\n[TimeControl "600"]\n[Termination "muratmerttaykan won by resignation"]\n[StartTime "14:12:25"]\n[EndDate "2020.01.16"]\n[EndTime "14:18:44"]\n[Link "https://www.chess.com/game/live/4404434819"]\n\n1. e4 {[%clk 0:09:54.4]} 1... e5 {[%clk 0:09:56.1]} 2. Nf3 {[%clk 0:09:35.6]} 2... Nf6 {[%clk 0:09:53.3]} 3. d4 {[%clk 0:09:33.3]} 3... d5 {[%clk 0:09:50]} 4. dxe5 {[%clk 0:09:27.1]} 4... Nxe4 {[%clk 0:09:41]} 5. Bb5+ {[%clk 0:09:19.7]} 5... c6 {[%clk 0:09:35.8]} 6. Ba4 {[%clk 0:09:04.1]} 6... Bg4 {[%clk 0:09:18.2]} 7. Bg5 {[%clk 0:07:56]} 7... Nxg5 {[%clk 0:09:06.1]} 8. Nbd2 {[%clk 0:07:28.2]} 8... Nd7 {[%clk 0:09:02.5]} 9. h3 {[%clk 0:06:26.2]} 9... Bh5 {[%clk 0:08:56.5]} 10. O-O {[%clk 0:05:51.7]} 10... Bb4 {[%clk 0:08:38.2]} 11. c3 {[%clk 0:05:45.5]} 11... Ba5 {[%clk 0:08:35.6]} 12. Re1 {[%clk 0:05:40.7]} 12... Bc7 {[%clk 0:08:26.7]} 13. e6 {[%clk 0:05:37.4]} 13... fxe6 {[%clk 0:08:24.1]} 14. Rxe6+ {[%clk 0:05:33.4]} 14... Nxe6 {[%clk 0:08:15.4]} 0-1\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.01.16"]\n[Round "-"]\n[White "seb810"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "2kr3r/pp1q1ppp/2p5/3pp3/1P1b4/P1N3P1/1BP4P/R3K2Q w KQ -"]\n[Timezone "UTC"]\n[ECO "A00"]\n[ECOUrl "https://www.chess.com/openings/Amar-Opening-1...d5-2.g3-e5"]\n[UTCDate "2020.01.16"]\n[UTCTime "14:20:05"]\n[WhiteElo "576"]\n[BlackElo "700"]\n[TimeControl "600"]\n[Termination "Hallsand won - game abandoned"]\n[StartTime "14:20:05"]\n[EndDate "2020.01.16"]\n[EndTime "14:29:51"]\n[Link "https://www.chess.com/game/live/4404454306"]\n\n1. g3 {[%clk 0:09:53.5]} 1... e5 {[%clk 0:09:51.7]} 2. Nh3 {[%clk 0:09:39.5]} 2... d5 {[%clk 0:09:36.8]} 3. Bg2 {[%clk 0:09:33.5]} 3... Nf6 {[%clk 0:09:32.5]} 4. e3 {[%clk 0:09:25.5]} 4... Bg4 {[%clk 0:09:18.4]} 5. Bf3 {[%clk 0:09:06.3]} 5... Bxh3 {[%clk 0:09:14.3]} 6. d4 {[%clk 0:09:00.4]} 6... Nc6 {[%clk 0:08:54.2]} 7. Nc3 {[%clk 0:08:47.3]} 7... Bb4 {[%clk 0:07:16.8]} 8. a3 {[%clk 0:08:40.4]} 8... Ba5 {[%clk 0:07:13.5]} 9. b4 {[%clk 0:08:38.1]} 9... Bb6 {[%clk 0:06:34.8]} 10. Bh5 {[%clk 0:08:27.2]} 10... Nxd4 {[%clk 0:05:49]} 11. exd4 {[%clk 0:08:21.7]} 11... Bxd4 {[%clk 0:05:46.7]} 12. Bb2 {[%clk 0:08:16.5]} 12... Qd7 {[%clk 0:05:14.5]} 13. Qe2 {[%clk 0:08:02.7]} 13... Bg4 {[%clk 0:05:09.2]} 14. Bxg4 {[%clk 0:07:39.4]} 14... Nxg4 {[%clk 0:04:33.1]} 15. Qb5 {[%clk 0:07:26.3]} 15... c6 {[%clk 0:04:25.9]} 16. Qd3 {[%clk 0:07:10.9]} 16... Nxf2 {[%clk 0:04:14.8]} 17. Qf3 {[%clk 0:06:57.5]} 17... Nxh1 {[%clk 0:04:09.7]} 18. Qxh1 {[%clk 0:06:55.4]} 18... O-O-O {[%clk 0:03:29.2]} 0-1\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.01.16"]\n[Round "-"]\n[White "Hallsand"]\n[Black "Maxkot773"]\n[Result "0-1"]\n[CurrentPosition "r2qk3/1ppbb3/p3p1p1/7r/1n2N3/P1N1P2Q/1PP3PP/R4RK1 w q -"]\n[Timezone "UTC"]\n[ECO "B01"]\n[ECOUrl "https://www.chess.com/openings/Scandinavian-Defense"]\n[UTCDate "2020.01.16"]\n[UTCTime "16:29:12"]\n[WhiteElo "642"]\n[BlackElo "589"]\n[TimeControl "600"]\n[Termination "Maxkot773 won by resignation"]\n[StartTime "16:29:12"]\n[EndDate "2020.01.16"]\n[EndTime "16:40:34"]\n[Link "https://www.chess.com/game/live/4404808791"]\n\n1. e4 {[%clk 0:09:59.9]} 1... d5 {[%clk 0:09:57.2]} 2. d3 {[%clk 0:09:47.6]} 2... f5 {[%clk 0:09:46.4]} 3. Nc3 {[%clk 0:09:28.9]} 3... e6 {[%clk 0:09:42.4]} 4. Nf3 {[%clk 0:08:57.5]} 4... Nf6 {[%clk 0:09:38.6]} 5. Be3 {[%clk 0:08:26.2]} 5... fxe4 {[%clk 0:09:33.2]} 6. dxe4 {[%clk 0:08:12.9]} 6... dxe4 {[%clk 0:09:28.2]} 7. Bb5+ {[%clk 0:06:47.9]} 7... Nc6 {[%clk 0:09:08.5]} 8. Nd2 {[%clk 0:06:17]} 8... Nd5 {[%clk 0:08:43.3]} 9. Ndxe4 {[%clk 0:05:18. ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.08.30"]\n[Round "-"]\n[White "Hallsand"]\n[Black "FreekHeesen"]\n[Result "0-1"]\n[CurrentPosition "8/5P2/3kp1q1/p7/3n2P1/6KP/r7/8 w - -"]\n[Timezone "UTC"]\n[ECO "A04"]\n[ECOUrl "https://www.chess.com/openings/Reti-Opening-Queens-Gambit-Invitation"]\n[UTCDate "2021.08.30"]\n[UTCTime "21:56:59"]\n[WhiteElo "753"]\n[BlackElo "725"]\n[TimeControl "300"]\n[Termination "FreekHeesen won by resignation"]\n[StartTime "21:56:59"]\n[EndDate "2021.08.30"]\n[EndTime "22:03:20"]\n[Link "https://www.chess.com/game/live/24099489693"]\n\n1. Nf3 {[%clk 0:05:00]} 1... e6 {[%clk 0:04:58.7]} 2. g3 {[%clk 0:04:57.8]} 2... Nc6 {[%clk 0:04:57.7]} 3. Bg2 {[%clk 0:04:56.5]} 3... Bd6 {[%clk 0:04:57]} 4. O-O {[%clk 0:04:55.4]} 4... Qf6 {[%clk 0:04:56.4]} 5. d3 {[%clk 0:04:54.7]} 5... Nh6 {[%clk 0:04:54.4]} 6. Nbd2 {[%clk 0:04:52]} 6... O-O {[%clk 0:04:53.7]} 7. e4 {[%clk 0:04:51.6]} 7... b5 {[%clk 0:04:48.2]} 8. Re1 {[%clk 0:04:47.7]} 8... Bc5 {[%clk 0:04:44.6]} 9. c3 {[%clk 0:04:36.5]} 9... Bb7 {[%clk 0:04:39.3]} 10. d4 {[%clk 0:04:35.4]} 10... Be7 {[%clk 0:04:36.4]} 11. e5 {[%clk 0:04:34.4]} 11... Qf5 {[%clk 0:04:25.9]} 12. Nh4 {[%clk 0:04:18.9]} 12... Qg4 {[%clk 0:04:15.6]} 13. Ndf3 {[%clk 0:04:12.5]} 13... Nxd4 {[%clk 0:03:55.8]} 14. cxd4 {[%clk 0:04:09.2]} 14... Bxh4 {[%clk 0:03:53.2]} 15. Nxh4 {[%clk 0:04:05.9]} 15... Bxg2 {[%clk 0:03:47.9]} 16. Kxg2 {[%clk 0:04:02.1]} 16... Qxd1 {[%clk 0:03:33.9]} 17. Rxd1 {[%clk 0:04:00.6]} 17... Ng4 {[%clk 0:03:31.8]} 18. Rd3 {[%clk 0:03:29.2]} 18... f6 {[%clk 0:03:27.5]} 19. h3 {[%clk 0:03:25.3]} 19... Nh6 {[%clk 0:03:24.1]} 20. Bd2 {[%clk 0:03:17.3]} 20... fxe5 {[%clk 0:03:23.3]} 21. dxe5 {[%clk 0:03:15.9]} 21... d5 {[%clk 0:03:20.6]} 22. exd6 {[%clk 0:03:11.7]} 22... cxd6 {[%clk 0:03:19.8]} 23. Rxd6 {[%clk 0:03:08.9]} 23... Rad8 {[%clk 0:03:19.1]} 24. Bb4 {[%clk 0:03:04]} 24... Rxd6 {[%clk 0:03:17.8]} 25. Bxd6 {[%clk 0:03:02.8]} 25... Rc8 {[%clk 0:03:15.8]} 26. Rd1 {[%clk 0:02:56.9]} 26... Rc2 {[%clk 0:03:11.6]} 27. Ba3 {[%clk 0:02:48.4]} 27... a5 {[%clk 0:03:04.2]} 28. Rd8+ {[%clk 0:02:43]} 28... Kf7 {[%clk 0:03:03.1]} 29. Bc5 {[%clk 0:02:26.8]} 29... Rxc5 {[%clk 0:03:00.1]} 30. Nf3 {[%clk 0:02:17.5]} 30... Rc2 {[%clk 0:02:58.9]} 31. Ne5+ {[%clk 0:02:13.9]} 31... Kf6 {[%clk 0:02:55]} 32. Nd7+ {[%clk 0:02:08.6]} 32... Ke7 {[%clk 0:02:54.2]} 33. Rh8 {[%clk 0:01:53.9]} 33... Kxd7 {[%clk 0:02:52.4]} 34. Rxh7 {[%clk 0:01:53.6]} 34... Rxb2 {[%clk 0:02:51.5]} 35. Rxg7+ {[%clk 0:01:50.9]} 35... Kd6 {[%clk 0:02:45.8]} 36. Kf3 {[%clk 0:01:45.4]} 36... Nf5 {[%clk 0:02:43.4]} 37. Rg6 {[%clk 0:01:41.8]} 37... Rxa2 {[%clk 0:02:40.6]} 38. g4 {[%clk 0:01:40.8]} 38... Nd4+ {[%clk 0:02:39.3]} 39. Kg3 {[%clk 0:01:37.2]} 39... b4 {[%clk 0:02:38.7]} 40. f4 {[%clk 0:01:31.9]} 40... b3 {[%clk 0:02:38.1]} 41. f5 {[%clk 0:01:31.2]} 41... b2 {[%clk 0:02:36.9]} 42. f6 {[%clk 0:01:29.4]} 42... b1=Q {[%clk 0:02:35.5]} 43. f7 {[%clk 0:01:28.3]} 43... Qxg6 {[%clk 0:02:34.2]} 0-1\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.08.30"]\n[Round "-"]\n[White "Hatchdog"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "r3k2r/p2nb1pb/2p2n1p/5N2/3P4/8/PPP3PP/R1B1KB1R b KQkq -"]\n[Timezone "UTC"]\n[ECO "B10"]\n[ECOUrl "https://www.chess.com/openings/Caro-Kann-Defense"]\n[UTCDate "2021.08.30"]\n[UTCTime "22:03:27"]\n[WhiteElo "771"]\n[BlackElo "765"]\n[TimeControl "300"]\n[Termination "Hallsand won by resignation"]\n[StartTime "22:03:27"]\n[EndDate "2021.08.30"]\n[EndTime "22:06:28"]\n[Link "https://www.chess.com/game/live/24100042045"]\n\n1. e4 {[%clk 0:05:00]} 1... c6 {[%clk 0:04:58.7]} 2. f4 {[%clk 0:04:57]} 2... d5 {[%clk 0:04:56.5]} 3. Nc3 {[%clk 0:04:52.4]} 3... dxe4 {[%clk 0:04:55]} 4. Nxe4 {[%clk 0:04:51.1]} 4... Bf5 {[%clk 0:04:54.6]} 5. Ng3 {[%clk 0:04:46.3]} 5... e6 {[%clk 0:04:44.7]} 6. Nf3 {[%clk 0:04:37.1]} 6... Bg6 {[%clk 0:04:41.1]} 7. Qe2 {[%clk 0:04:29]} 7... h6 {[%clk 0:04:39]} 8. f5 {[%clk 0:04:27.8]} 8... Bh7 {[%clk 0:04:35.9]} 9. fxe6 {[%clk 0:04:26.9]} ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.05.03"]\n[Round "-"]\n[White "Hallsand"]\n[Black "tuc04481"]\n[Result "1-0"]\n[CurrentPosition "1n3R1k/2p3pp/p7/2PB4/Q2p4/P2q2P1/3n3P/R5K1 b - -"]\n[Timezone "UTC"]\n[ECO "A07"]\n[ECOUrl "https://www.chess.com/openings/Kings-Indian-Attack"]\n[UTCDate "2021.05.03"]\n[UTCTime "20:53:50"]\n[WhiteElo "770"]\n[BlackElo "763"]\n[TimeControl "300"]\n[Termination "Hallsand won by checkmate"]\n[StartTime "20:53:50"]\n[EndDate "2021.05.03"]\n[EndTime "20:59:45"]\n[Link "https://www.chess.com/game/live/13814039851"]\n\n1. Nf3 {[%clk 0:04:57.8]} 1... d5 {[%clk 0:04:56.6]} 2. g3 {[%clk 0:04:54.7]} 2... d4 {[%clk 0:04:54.4]} 3. d3 {[%clk 0:04:53.4]} 3... Nc6 {[%clk 0:04:52.3]} 4. Bg2 {[%clk 0:04:50.2]} 4... Bg4 {[%clk 0:04:50.9]} 5. O-O {[%clk 0:04:48.5]} 5... Bxf3 {[%clk 0:04:49.5]} 6. Bxf3 {[%clk 0:04:46.6]} 6... e5 {[%clk 0:04:48.4]} 7. e4 {[%clk 0:04:45.9]} 7... Nge7 {[%clk 0:04:40.5]} 8. Nd2 {[%clk 0:04:40.1]} 8... Ng6 {[%clk 0:04:39]} 9. c4 {[%clk 0:04:37.7]} 9... Bc5 {[%clk 0:04:33.6]} 10. a3 {[%clk 0:04:27.4]} 10... O-O {[%clk 0:04:31]} 11. b4 {[%clk 0:04:26]} 11... Be7 {[%clk 0:04:23.9]} 12. Bg2 {[%clk 0:04:23.2]} 12... a6 {[%clk 0:04:13.8]} 13. Nf3 {[%clk 0:04:10.6]} 13... b6 {[%clk 0:04:06]} 14. Bd2 {[%clk 0:03:52.2]} 14... Qd7 {[%clk 0:03:55]} 15. Qc2 {[%clk 0:03:29.2]} 15... f5 {[%clk 0:03:49.9]} 16. exf5 {[%clk 0:03:18.2]} 16... Qxf5 {[%clk 0:03:48.3]} 17. Rfe1 {[%clk 0:03:13.8]} 17... Bd6 {[%clk 0:03:37.7]} 18. c5 {[%clk 0:03:00]} 18... bxc5 {[%clk 0:03:35.5]} 19. bxc5 {[%clk 0:02:59.1]} 19... Be7 {[%clk 0:03:27]} 20. Qa4 {[%clk 0:02:45.5]} 20... Nb8 {[%clk 0:03:14.1]} 21. Nxe5 {[%clk 0:02:32.1]} 21... Nxe5 {[%clk 0:03:10.1]} 22. Bxa8 {[%clk 0:02:30.1]} 22... Nf3+ {[%clk 0:03:06.1]} 23. Kf1 {[%clk 0:02:27.5]} 23... Nxd2+ {[%clk 0:03:01.7]} 24. Kg2 {[%clk 0:02:21.3]} 24... Qf3+ {[%clk 0:02:58.7]} 25. Kg1 {[%clk 0:02:17.1]} 25... Qxd3 {[%clk 0:02:50.2]} 26. Rxe7 {[%clk 0:02:08.5]} 26... Rxf2 {[%clk 0:02:40.5]} 27. Re8+ {[%clk 0:02:04.5]} 27... Rf8 {[%clk 0:02:37.4]} 28. Bd5+ {[%clk 0:01:52.5]} 28... Kh8 {[%clk 0:02:28.8]} 29. Rxf8# {[%clk 0:01:51.3]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.05.03"]\n[Round "-"]\n[White "Hallsand"]\n[Black "Chaps95114"]\n[Result "1-0"]\n[CurrentPosition "r7/pp3k2/5Pr1/2P1n2Q/1P1pP3/P2P2P1/6BP/R4RK1 w - -"]\n[Timezone "UTC"]\n[ECO "A07"]\n[ECOUrl "https://www.chess.com/openings/Kings-Indian-Attack"]\n[UTCDate "2021.05.03"]\n[UTCTime "21:10:03"]\n[WhiteElo "779"]\n[BlackElo "799"]\n[TimeControl "300"]\n[Termination "Hallsand won by resignation"]\n[StartTime "21:10:03"]\n[EndDate "2021.05.03"]\n[EndTime "21:14:47"]\n[Link "https://www.chess.com/game/live/13815164311"]\n\n1. Nf3 {[%clk 0:05:00]} 1... d5 {[%clk 0:04:58]} 2. g3 {[%clk 0:04:58]} 2... e6 {[%clk 0:04:51.5]} 3. Bg2 {[%clk 0:04:55.9]} 3... Bd6 {[%clk 0:04:49.9]} 4. O-O {[%clk 0:04:54]} 4... e5 {[%clk 0:04:48.3]} 5. d3 {[%clk 0:04:52.6]} 5... f5 {[%clk 0:04:45.9]} 6. Nbd2 {[%clk 0:04:50.4]} 6... e4 {[%clk 0:04:43.3]} 7. Nd4 {[%clk 0:04:44.5]} 7... Be6 {[%clk 0:04:41.5]} 8. Nxe6 {[%clk 0:04:39.7]} 8... Qe7 {[%clk 0:04:38.3]} 9. Nd4 {[%clk 0:04:38]} 9... Nd7 {[%clk 0:04:36.7]} 10. a3 {[%clk 0:04:21.8]} 10... h5 {[%clk 0:04:32.6]} 11. Nxf5 {[%clk 0:04:14.4]} 11... Qf6 {[%clk 0:04:29.3]} 12. Nxd6+ {[%clk 0:04:07.7]} 12... cxd6 {[%clk 0:04:26.7]} 13. b4 {[%clk 0:04:05.5]} 13... g5 {[%clk 0:04:24.3]} 14. c4 {[%clk 0:04:02.5]} 14... d4 {[%clk 0:04:19.8]} 15. Nxe4 {[%clk 0:03:56.8]} 15... Qf5 {[%clk 0:04:16.9]} 16. Bxg5 {[%clk 0:03:51.2]} 16... Ne7 {[%clk 0:04:04.1]} 17. Nxd6+ {[%clk 0:03:46.3]} 17... Kf8 {[%clk 0:03:50.4]} 18. Nxf5 {[%clk 0:03:45.2]} 18... Nxf5 {[%clk 0:03:50.3]} 19. e4 {[%clk 0:03:28.5]} 19... Nd6 {[%clk 0:03:33.4]} 20. c5 {[%clk 0:03:24.6]} 20... Nf7 {[%clk 0:03:29.4]} 21. Bh4 {[%clk 0:03:15.3]} 21... Nde5 {[%clk 0:03:25.3]} 22. f4 {[%clk 0:03:10.1]} 22... Ng6 {[%clk 0:03:21.8]} 23. Bf6 {[%clk 0:02:56.5]} 23... Rg8 {[%clk 0:03:18]} 24. f5 {[%clk 0:02:5 ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.03.01"]\n[Round "-"]\n[White "Hallsand"]\n[Black "zlatama"]\n[Result "1-0"]\n[CurrentPosition "2B2b1r/7p/1p3p2/p4P2/P2P1P1N/2p3P1/3k1R1P/6K1 b - -"]\n[Timezone "UTC"]\n[ECO "D02"]\n[ECOUrl "https://www.chess.com/openings/Queens-Pawn-Opening-Zukertort-Variation"]\n[UTCDate "2021.03.01"]\n[UTCTime "14:21:04"]\n[WhiteElo "692"]\n[BlackElo "659"]\n[TimeControl "300"]\n[Termination "Hallsand won on time"]\n[StartTime "14:21:04"]\n[EndDate "2021.03.01"]\n[EndTime "14:31:09"]\n[Link "https://www.chess.com/game/live/8347461753"]\n\n1. Nf3 {[%clk 0:05:00]} 1... d5 {[%clk 0:04:58.9]} 2. d4 {[%clk 0:04:58.6]} 2... Nf6 {[%clk 0:04:51.7]} 3. Bg5 {[%clk 0:04:57.5]} 3... Nc6 {[%clk 0:04:48.2]} 4. Bxf6 {[%clk 0:04:56.1]} 4... gxf6 {[%clk 0:04:43.3]} 5. g3 {[%clk 0:04:55.5]} 5... Bf5 {[%clk 0:04:39.1]} 6. Bg2 {[%clk 0:04:51.5]} 6... Nb4 {[%clk 0:04:27.8]} 7. Na3 {[%clk 0:04:39.2]} 7... e6 {[%clk 0:04:18.4]} 8. c3 {[%clk 0:04:36.1]} 8... Nc6 {[%clk 0:04:02.2]} 9. O-O {[%clk 0:04:33.9]} 9... e5 {[%clk 0:03:46.7]} 10. Nh4 {[%clk 0:04:18]} 10... Ne7 {[%clk 0:03:34]} 11. Re1 {[%clk 0:04:00.1]} 11... c6 {[%clk 0:03:21.9]} 12. e4 {[%clk 0:03:31.6]} 12... Qb6 {[%clk 0:03:16.1]} 13. exf5 {[%clk 0:03:22.3]} 13... exd4 {[%clk 0:03:01.4]} 14. cxd4 {[%clk 0:02:46.7]} 14... Qxb2 {[%clk 0:02:51.9]} 15. Nc2 {[%clk 0:02:39.5]} 15... O-O-O {[%clk 0:02:39.9]} 16. Qc1 {[%clk 0:02:24.1]} 16... Qxc1 {[%clk 0:02:13.4]} 17. Raxc1 {[%clk 0:02:19.9]} 17... Bh6 {[%clk 0:02:10.2]} 18. f4 {[%clk 0:02:02.4]} 18... Rde8 {[%clk 0:01:51.2]} 19. Re2 {[%clk 0:01:17.5]} 19... b6 {[%clk 0:01:43.9]} 20. Rce1 {[%clk 0:01:15.7]} 20... Kd8 {[%clk 0:01:37.6]} 21. Nb4 {[%clk 0:01:09]} 21... c5 {[%clk 0:01:31.6]} 22. Nxd5 {[%clk 0:00:56.4]} 22... Nxd5 {[%clk 0:01:15.7]} 23. Bxd5 {[%clk 0:00:53.6]} 23... a6 {[%clk 0:00:59.3]} 24. Bxf7 {[%clk 0:00:46.1]} 24... Rxe2 {[%clk 0:00:32.5]} 25. Rxe2 {[%clk 0:00:44.7]} 25... Bf8 {[%clk 0:00:27.4]} 26. Re8+ {[%clk 0:00:40.4]} 26... Kd7 {[%clk 0:00:22]} 27. Re2 {[%clk 0:00:29]} 27... a5 {[%clk 0:00:17.5]} 28. a4 {[%clk 0:00:27]} 28... c4 {[%clk 0:00:11.1]} 29. Be6+ {[%clk 0:00:23]} 29... Kd6 {[%clk 0:00:07.5]} 30. Bc8 {[%clk 0:00:19.5]} 30... Kd5 {[%clk 0:00:04.5]} 31. Rd2 {[%clk 0:00:17.8]} 31... Ke4 {[%clk 0:00:03.1]} 32. Re2+ {[%clk 0:00:16.7]} 32... Kd3 {[%clk 0:00:01.7]} 33. Re1 {[%clk 0:00:15]} 33... Kd2 {[%clk 0:00:01]} 34. Rf1 {[%clk 0:00:13.3]} 34... c3 {[%clk 0:00:00.5]} 35. Rf2+ {[%clk 0:00:12.3]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.03.01"]\n[Round "-"]\n[White "joshthorns"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "4n1k1/1B3p2/6p1/1Npr3p/5P1K/PP4P1/7r/2R5 w - -"]\n[Timezone "UTC"]\n[ECO "A00"]\n[ECOUrl "https://www.chess.com/openings/Kings-Fianchetto-Opening-Indian-Defense"]\n[UTCDate "2021.03.01"]\n[UTCTime "18:10:58"]\n[WhiteElo "680"]\n[BlackElo "700"]\n[TimeControl "300"]\n[Termination "Hallsand won by checkmate"]\n[StartTime "18:10:58"]\n[EndDate "2021.03.01"]\n[EndTime "18:19:11"]\n[Link "https://www.chess.com/game/live/8361276183"]\n\n1. g3 {[%clk 0:04:54.4]} 1... Nf6 {[%clk 0:04:57]} 2. Bg2 {[%clk 0:04:52.5]} 2... d5 {[%clk 0:04:55.4]} 3. b3 {[%clk 0:04:51.5]} 3... g6 {[%clk 0:04:54.6]} 4. d4 {[%clk 0:04:48.6]} 4... Bg7 {[%clk 0:04:53.6]} 5. Bb2 {[%clk 0:04:46.4]} 5... O-O {[%clk 0:04:52.1]} 6. e3 {[%clk 0:04:44.9]} 6... Nbd7 {[%clk 0:04:51.1]} 7. f3 {[%clk 0:04:32.8]} 7... c5 {[%clk 0:04:49.7]} 8. e4 {[%clk 0:04:28.5]} 8... e5 {[%clk 0:04:37.1]} 9. dxe5 {[%clk 0:04:25.9]} 9... Ne8 {[%clk 0:04:28.4]} 10. exd5 {[%clk 0:04:09.7]} 10... Nxe5 {[%clk 0:04:24.5]} 11. f4 {[%clk 0:03:51.3]} 11... Bg4 {[%clk 0:04:17.3]} 12. Qd2 {[%clk 0:03:42.8]} 12... Nd7 {[%clk 0:04:07.7]} 13. Bxg7 {[%clk 0:03:31.5]} 13... Nxg7 {[%clk 0:04:05.6]} 14. Nc3 {[%clk 0:03:27]} 14... Re8+ {[%clk 0:03:51.6]} 15. Kf1 {[%clk 0:03:19.2]} 15... Rc8 {[%clk 0:03:39.6]} 16. Nb5 {[%clk 0:03:14.4]} 16... Nb6 {[%clk 0:03:35.3]} 17. Nxa7 {[%clk 0:03:09.4]} 17... Rc7 {[%clk 0:0 ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.11.25"]\n[Round "-"]\n[White "jeffersonalmeida_3"]\n[Black "Hallsand"]\n[Result "1-0"]\n[CurrentPosition "5r1k/8/7N/5P2/8/1b5P/p5PK/3r4 b - -"]\n[Timezone "UTC"]\n[ECO "C21"]\n[ECOUrl "https://www.chess.com/openings/Center-Game-Accepted-Kieseritzky-Variation-3...Bc5"]\n[UTCDate "2020.11.25"]\n[UTCTime "00:40:03"]\n[WhiteElo "569"]\n[BlackElo "800"]\n[TimeControl "600"]\n[Termination "jeffersonalmeida_3 won on time"]\n[StartTime "00:40:03"]\n[EndDate "2020.11.25"]\n[EndTime "01:00:12"]\n[Link "https://www.chess.com/game/live/5815098847"]\n\n1. e4 {[%clk 0:09:59.9]} 1... e5 {[%clk 0:09:59.9]} 2. d4 {[%clk 0:09:57.3]} 2... exd4 {[%clk 0:09:21.4]} 3. Nf3 {[%clk 0:09:47.9]} 3... Bc5 {[%clk 0:09:02.6]} 4. Bg5 {[%clk 0:09:35]} 4... Ne7 {[%clk 0:08:51.4]} 5. Nxd4 {[%clk 0:09:28.9]} 5... h6 {[%clk 0:08:39.6]} 6. Qg4 {[%clk 0:08:56.2]} 6... Bxd4 {[%clk 0:08:23.3]} 7. Bxe7 {[%clk 0:07:53.8]} 7... Qxe7 {[%clk 0:07:56]} 8. Bb5 {[%clk 0:07:26.4]} 8... O-O {[%clk 0:07:49.9]} 9. O-O {[%clk 0:06:46.2]} 9... d6 {[%clk 0:07:13]} 10. Rd1 {[%clk 0:06:38.9]} 10... Bxg4 {[%clk 0:07:10.3]} 11. Rxd4 {[%clk 0:06:31.1]} 11... Qe5 {[%clk 0:06:21.1]} 12. Rc4 {[%clk 0:05:53.6]} 12... c6 {[%clk 0:05:38.4]} 13. Na3 {[%clk 0:05:23.4]} 13... cxb5 {[%clk 0:05:07.2]} 14. Rc7 {[%clk 0:04:59.9]} 14... Qxe4 {[%clk 0:04:30.9]} 15. Nxb5 {[%clk 0:04:52.6]} 15... Nc6 {[%clk 0:04:10.4]} 16. Nxd6 {[%clk 0:04:44.2]} 16... Qxc2 {[%clk 0:03:32.4]} 17. Nxb7 {[%clk 0:04:15.5]} 17... Qxb2 {[%clk 0:03:18.2]} 18. Re1 {[%clk 0:03:58]} 18... Qb3 {[%clk 0:03:18.1]} 19. h3 {[%clk 0:03:12.3]} 19... Rfe8 {[%clk 0:02:56.4]} 20. axb3 {[%clk 0:03:06.2]} 20... Rxe1+ {[%clk 0:02:53.1]} 21. Kh2 {[%clk 0:02:55.1]} 21... Be6 {[%clk 0:02:29.2]} 22. Nd6 {[%clk 0:02:26.4]} 22... a5 {[%clk 0:01:23.1]} 23. Rxc6 {[%clk 0:02:15.2]} 23... Bxb3 {[%clk 0:01:02.1]} 24. f4 {[%clk 0:01:38.9]} 24... a4 {[%clk 0:00:54]} 25. Rc3 {[%clk 0:01:22.3]} 25... Rd1 {[%clk 0:00:41.1]} 26. Nf5 {[%clk 0:00:57.7]} 26... Rb8 {[%clk 0:00:26]} 27. Rg3 {[%clk 0:00:49.2]} 27... Kh7 {[%clk 0:00:06.5]} 28. Rxg7+ {[%clk 0:00:43.8]} 28... Kh8 {[%clk 0:00:03.4]} 29. Rxf7 {[%clk 0:00:37.9]} 29... a3 {[%clk 0:00:02.6]} 30. Nxh6 {[%clk 0:00:30.3]} 30... a2 {[%clk 0:00:02.5]} 31. Rf8+ {[%clk 0:00:23.5]} 31... Rxf8 {[%clk 0:00:00.3]} 32. f5 {[%clk 0:00:07.4]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.11.25"]\n[Round "-"]\n[White "Hallsand"]\n[Black "jeffersonalmeida_3"]\n[Result "0-1"]\n[CurrentPosition "r3r1k1/ppp2ppp/8/3p3P/1P2n2P/5Nq1/1PPP1pK1/R1BQ1B1R w - -"]\n[Timezone "UTC"]\n[ECO "C42"]\n[ECOUrl "https://www.chess.com/openings/Petrovs-Defense-Three-Knights-Game"]\n[UTCDate "2020.11.25"]\n[UTCTime "01:03:26"]\n[WhiteElo "800"]\n[BlackElo "569"]\n[TimeControl "600+5"]\n[Termination "jeffersonalmeida_3 won by checkmate"]\n[StartTime "01:03:26"]\n[EndDate "2020.11.25"]\n[EndTime "01:14:14"]\n[Link "https://www.chess.com/game/live/5815195038"]\n\n1. e4 {[%clk 0:10:04.9]} 1... e5 {[%clk 0:10:04.9]} 2. Nf3 {[%clk 0:10:07.3]} 2... Nf6 {[%clk 0:09:57.4]} 3. Nc3 {[%clk 0:10:04.2]} 3... Bb4 {[%clk 0:09:57]} 4. a3 {[%clk 0:10:00]} 4... Nxe4 {[%clk 0:09:50.3]} 5. Nxe4 {[%clk 0:09:58.6]} 5... O-O {[%clk 0:09:48.5]} 6. axb4 {[%clk 0:10:00.4]} 6... d5 {[%clk 0:09:45.4]} 7. Nc5 {[%clk 0:09:28.5]} 7... Bg4 {[%clk 0:09:39.3]} 8. h3 {[%clk 0:09:23.8]} 8... Bh5 {[%clk 0:09:31.2]} 9. g4 {[%clk 0:09:24.6]} 9... e4 {[%clk 0:09:18.8]} 10. Nd4 {[%clk 0:09:14.7]} 10... Nd7 {[%clk 0:08:52.4]} 11. gxh5 {[%clk 0:09:04.7]} 11... Re8 {[%clk 0:08:47.6]} 12. f3 {[%clk 0:08:42]} 12... exf3+ {[%clk 0:08:26.1]} 13. Kf2 {[%clk 0:08:26.7]} 13... Qh4+ {[%clk 0:08:09.8]} 14. Kg1 {[%clk 0:07:59.6]} 14... f2+ {[%clk 0:08:07.4]} 15. Kh2 {[%clk 0:07:38.1]} 15... Nxc5 {[%clk 0:07:36.6]} 16. Nf3 {[%clk 0:07:25.1]} 16... Qf4+ {[%clk 0:06:55.2]} 17. Kg2 {[%clk 0:07:00.8]} 17... Ne4 {[%clk 0:06:36.9]} 18. h4 {[%clk 0:06:02.3]} 18... Qg3# {[%clk 0:06:18.8]} 0-1\n', '[Event "Live Chess"]\n[Site "Chess.c ...
# ['[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.09.24"]\n[Round "-"]\n[White "Hallsand"]\n[Black "wqipri24pu4"]\n[Result "1-0"]\n[CurrentPosition "rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq e3"]\n[Timezone "UTC"]\n[ECO "B00"]\n[ECOUrl "https://www.chess.com/openings/Kings-Pawn-Opening"]\n[UTCDate "2020.09.24"]\n[UTCTime "16:13:16"]\n[WhiteElo "630"]\n[BlackElo "613"]\n[TimeControl "300"]\n[Termination "Hallsand won - game abandoned"]\n[StartTime "16:13:16"]\n[EndDate "2020.09.24"]\n[EndTime "16:13:40"]\n[Link "https://www.chess.com/game/live/5491613546"]\n\n1. e4 {[%clk 0:04:58]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.09.24"]\n[Round "-"]\n[White "redho31"]\n[Black "Hallsand"]\n[Result "1-0"]\n[CurrentPosition "8/1p3pkp/1P6/1b4P1/6P1/8/4p3/4K3 b - -"]\n[Timezone "UTC"]\n[ECO "C45"]\n[ECOUrl "https://www.chess.com/openings/Scotch-Game-3...exd4-4.Nxd4"]\n[UTCDate "2020.09.24"]\n[UTCTime "16:13:53"]\n[WhiteElo "542"]\n[BlackElo "598"]\n[TimeControl "300"]\n[Termination "redho31 won on time"]\n[StartTime "16:13:53"]\n[EndDate "2020.09.24"]\n[EndTime "16:21:37"]\n[Link "https://www.chess.com/game/live/5491616174"]\n\n1. e4 {[%clk 0:04:52.7]} 1... e5 {[%clk 0:04:57.7]} 2. Nf3 {[%clk 0:04:43.8]} 2... Nc6 {[%clk 0:04:52.9]} 3. d4 {[%clk 0:04:39]} 3... exd4 {[%clk 0:04:44.4]} 4. Nxd4 {[%clk 0:04:37.4]} 4... Nge7 {[%clk 0:04:24]} 5. Nb5 {[%clk 0:04:27.4]} 5... d6 {[%clk 0:03:51.4]} 6. a4 {[%clk 0:04:16.2]} 6... Be6 {[%clk 0:03:45]} 7. b3 {[%clk 0:04:13.7]} 7... d5 {[%clk 0:03:22.4]} 8. Be3 {[%clk 0:04:08.8]} 8... dxe4 {[%clk 0:03:04.6]} 9. Qxd8+ {[%clk 0:04:03.6]} 9... Rxd8 {[%clk 0:02:54.4]} 10. Bf4 {[%clk 0:03:59.9]} 10... Nd5 {[%clk 0:02:43]} 11. N1a3 {[%clk 0:03:58.1]} 11... Bxa3 {[%clk 0:02:38.4]} 12. Rd1 {[%clk 0:03:56.3]} 12... O-O {[%clk 0:02:35.6]} 13. Bxc7 {[%clk 0:03:50.3]} 13... Rd7 {[%clk 0:01:59]} 14. Bd6 {[%clk 0:03:45]} 14... Rfd8 {[%clk 0:01:50.8]} 15. Bc7 {[%clk 0:03:40.7]} 15... Ne3 {[%clk 0:01:42.5]} 16. Rxd7 {[%clk 0:03:36.1]} 16... Rxd7 {[%clk 0:01:40.4]} 17. fxe3 {[%clk 0:03:32.2]} 17... Bb4+ {[%clk 0:01:33.9]} 18. c3 {[%clk 0:03:30]} 18... a6 {[%clk 0:01:13]} 19. cxb4 {[%clk 0:03:14.7]} 19... axb5 {[%clk 0:01:11.3]} 20. Bxb5 {[%clk 0:03:13.7]} 20... Rxc7 {[%clk 0:00:56.6]} 21. Bxc6 {[%clk 0:03:02.8]} 21... Rxc6 {[%clk 0:00:54.9]} 22. O-O {[%clk 0:03:01.8]} 22... Rc3 {[%clk 0:00:38.5]} 23. Rb1 {[%clk 0:02:48.8]} 23... Rxe3 {[%clk 0:00:36.9]} 24. b5 {[%clk 0:02:46.5]} 24... Rxb3 {[%clk 0:00:20.3]} 25. Rxb3 {[%clk 0:02:44.9]} 25... Bxb3 {[%clk 0:00:18.7]} 26. h3 {[%clk 0:02:43.9]} 26... Bxa4 {[%clk 0:00:17.1]} 27. b6 {[%clk 0:02:41.7]} 27... e3 {[%clk 0:00:15.1]} 28. Kf1 {[%clk 0:02:40.4]} 28... Bb5+ {[%clk 0:00:12.6]} 29. Ke1 {[%clk 0:02:39.2]} 29... e2 {[%clk 0:00:09.7]} 30. g4 {[%clk 0:02:37.7]} 30... g5 {[%clk 0:00:02.6]} 31. h4 {[%clk 0:02:33.6]} 31... Kg7 {[%clk 0:00:00.9]} 32. hxg5 {[%clk 0:02:32.2]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.09.25"]\n[Round "-"]\n[White "Hallsand"]\n[Black "angelmartinez11"]\n[Result "1-0"]\n[CurrentPosition "rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq e3"]\n[Timezone "UTC"]\n[ECO "B00"]\n[ECOUrl "https://www.chess.com/openings/Kings-Pawn-Opening"]\n[UTCDate "2020.09.25"]\n[UTCTime "23:59:18"]\n[WhiteElo "621"]\n[BlackElo "595"]\n[TimeControl "300"]\n[Termination "Hallsand won - game abandoned"]\n[StartTime "23:59:18"]\n[EndDate "2020.09.25"]\n[EndTime "23:59:39"]\n[Link "https://www.chess.com/game/live/5498085208"]\n\n1. e4 {[%clk 0:04:59.9]} 1-0\n', '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2020.09.26"]\n[Round "-"]\n[White "Hallsand"]\n[Black "the_big_josh"]\n[Result "1-0"]\n[CurrentPosition "rn2kb1r/p1p1pp1p/1p4p1/3b4/3N1BB1/6P1/PPP2P1P/R2Q1RK1 b kq -"]\n[Timezone "UTC"]\n[ECO "B01"]\n[ECOUrl "https://www.chess.com/openings/Scandinavian-Defense-Mieses-Kotrc-Variation-3.Nc3"]\n[UTCDate "2020.09.26"]\n[UTCTime "00:00:01"]\n[WhiteElo "654"]\n[BlackElo "792"]\n[TimeControl "300"]\n[Termination "Ha ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-7c2e78aa699c> in <module>
#       6         data = []
#       7         for i in range(len(json.loads(data1[0])['games'])):
# ----> 8             data.append(json.loads(data1[0])['games'][i]['pgn'])
#       9
#      10         print(data)
#
# KeyError: 'pgn'

# %%
data[0]
# Out:
# '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2021.04.01"]\n[Round "-"]\n[White "Hallsand"]\n[Black "asad100000000"]\n[Result "1-0"]\n[CurrentPosition "1r1kR3/p5pp/2Qb1q2/2p5/3p4/1P1P3P/PBP2PB1/6K1 b - -"]\n[Timezone "UTC"]\n[ECO "A04"]\n[ECOUrl "https://www.chess.com/openings/Reti-Opening-Black-Mustang-Defense"]\n[UTCDate "2021.04.01"]\n[UTCTime "21:59:46"]\n[WhiteElo "701"]\n[BlackElo "666"]\n[TimeControl "300"]\n[Termination "Hallsand won by checkmate"]\n[StartTime "21:59:46"]\n[EndDate "2021.04.01"]\n[EndTime "22:07:13"]\n[Link "https://www.chess.com/game/live/11053424045"]\n\n1. Nf3 {[%clk 0:05:00]} 1... Nc6 {[%clk 0:04:57.5]} 2. g3 {[%clk 0:04:52.7]} 2... Nf6 {[%clk 0:04:56.7]} 3. Bg2 {[%clk 0:04:50.2]} 3... e6 {[%clk 0:04:55.6]} 4. d3 {[%clk 0:04:48.9]} 4... d5 {[%clk 0:04:54.2]} 5. O-O {[%clk 0:04:47.8]} 5... e5 {[%clk 0:04:39.3]} 6. Nbd2 {[%clk 0:04:46.4]} 6... Bd6 {[%clk 0:04:26.8]} 7. e4 {[%clk 0:04:43.8]} 7... dxe4 {[%clk 0:04:21.6]} 8. Nxe4 {[%clk 0:04:33.2]} 8... Bg4 {[%clk 0:04:16]} 9. Qd2 {[%clk 0:04:23.2]} 9... Nd4 {[%clk 0:04:08]} 10. Nxd4 {[%clk 0:03:34.8]} 10... exd4 {[%clk 0:04:00.6]} 11. b3 {[%clk 0:03:28.3]} 11... Nxe4 {[%clk 0:03:46.1]} 12. Bxe4 {[%clk 0:03:25.8]} 12... f5 {[%clk 0:03:23.3]} 13. Bg2 {[%clk 0:03:22.2]} 13... c5 {[%clk 0:03:13.3]} 14. Re1+ {[%clk 0:03:20.5]} 14... Kd7 {[%clk 0:02:59]} 15. Bxb7 {[%clk 0:03:16.4]} 15... Rb8 {[%clk 0:02:55.2]} 16. Bg2 {[%clk 0:03:05.1]} 16... Qf6 {[%clk 0:02:33.6]} 17. h3 {[%clk 0:03:00.8]} 17... Bh5 {[%clk 0:02:28.9]} 18. Bb2 {[%clk 0:02:46.7]} 18... f4 {[%clk 0:02:18.8]} 19. gxf4 {[%clk 0:02:42.5]} 19... Bxf4 {[%clk 0:02:15]} 20. Qe2 {[%clk 0:02:36.4]} 20... Rhe8 {[%clk 0:02:06]} 21. Qxh5 {[%clk 0:02:32.1]} 21... Rxe1+ {[%clk 0:02:01.6]} 22. Rxe1 {[%clk 0:02:30.1]} 22... Bd2 {[%clk 0:01:52.1]} 23. Re2 {[%clk 0:02:20.9]} 23... Bf4 {[%clk 0:01:27.2]} 24. Qd5+ {[%clk 0:02:16.6]} 24... Bd6 {[%clk 0:01:23]} 25. Qc6+ {[%clk 0:02:10.9]} 25... Kd8 {[%clk 0:01:15.7]} 26. Qe8+ {[%clk 0:01:59.1]} 26... Kc7 {[%clk 0:01:09.5]} 27. Qc6+ {[%clk 0:01:48.2]} 27... Kd8 {[%clk 0:01:04.5]} 28. Re8# {[%clk 0:01:42.7]} 1-0\n'

# %%
play = chess()

# %%
play.extract('Hallsand')
# Out:
# Solving Hallsand online data...
# Refilling folder /home/julio/Desktop/Data_Projects/chess/chess-analysis/PGN/hallsand/2021-11
# Hallsand data solved.
# Creating dataframe
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-33c7ab7560e7> in <module>
# ----> 1 play.extract('Hallsand')
#
# <ipython-input-135-6df58e76c3ff> in extract(self, player)
#     349                         data.append(json.loads(data1[0])['games'][i]['pgn'].split('\n'))
#     350
# --> 351                     start, end = data_delimiter(data) #defines the limits of each data part
#     352
#     353                     #print(data[start[k]:end[k]])
#
# <ipython-input-135-6df58e76c3ff> in data_delimiter(data)
#      75     for i,j in enumerate(data):
#      76
# ---> 77         if j.startswith("[Event"):
#      78             start.append(i)
#      79             if i != 0:
#
# AttributeError: 'list' object has no attribute 'startswith'

# %%
json.loads(data1[0])['games'][0]['pgn']
# Out:
# '[Event "Let\'s Play!"]\n[Site "Chess.com"]\n[Date "2020.01.30"]\n[Round "-"]\n[White "ClimatBR"]\n[Black "Hallsand"]\n[Result "0-1"]\n[CurrentPosition "2kr2r1/1ppq1p1p/p4b2/8/2PN1Pp1/4P2P/PP1B3n/2RK4 w - - 0 30"]\n[Timezone "UTC"]\n[ECO "A00"]\n[ECOUrl "https://www.chess.com/openings/Kings-Fianchetto-Opening-1...d5"]\n[UTCDate "2020.01.30"]\n[UTCTime "02:31:14"]\n[WhiteElo "1000"]\n[BlackElo "800"]\n[TimeControl "1/86400"]\n[Termination "Hallsand won by resignation"]\n[StartTime "02:31:14"]\n[EndDate "2020.02.15"]\n[EndTime "02:50:06"]\n[Link "https://www.chess.com/game/daily/249707158"]\n\n1. g3 {[%clk 23:59:00]} 1... d5 {[%clk 23:59:28]} 2. e3 {[%clk 14:54:49]} 2... Nc6 {[%clk 23:59:19]} 3. c3 {[%clk 19:17:52]} 3... Nf6 {[%clk 20:17:28]} 4. Qc2 {[%clk 23:31:32]} 4... e5 {[%clk 23:37:46]} 5. Nf3 {[%clk 18:52:46]} 5... Bg4 {[%clk 14:09:49]} 6. Be2 {[%clk 22:08:20]} 6... e4 {[%clk 22:43:35]} 7. Nh4 {[%clk 23:46:48]} 7... Bd6 {[%clk 23:35:33]} 8. h3 {[%clk 15:53:52]} 8... Bxe2 {[%clk 21:21:32]} 9. Kxe2 {[%clk 6:16:04]} 9... Ne5 {[%clk 22:12:43]} 10. d4 {[%clk 23:50:56]} 10... exd3+ {[%clk 9:56:44]} 11. Qxd3 {[%clk 17:21:37]} 11... Nxd3 {[%clk 23:57:41]} 12. Kxd3 {[%clk 23:58:42]} 12... Qd7 {[%clk 23:53:54]} 13. Na3 {[%clk 23:52:13]} 13... Ne4 {[%clk 23:09:20]} 14. Ke2 {[%clk 23:15:37]} 14... Ng5 {[%clk 21:28:11]} 15. f4 {[%clk 22:50:59]} 15... Ne4 {[%clk 23:36:44]} 16. Rh2 {[%clk 23:34:07]} 16... O-O-O {[%clk 4:10:12]} 17. Bd2 {[%clk 6:48:14]} 17... g5 {[%clk 23:34:26]} 18. Nf3 {[%clk 22:19:25]} 18... Nxg3+ {[%clk 16:47:08]} 19. Kf2 {[%clk 10:28:55]} 19... Ne4+ {[%clk 23:46:44]} 20. Ke1 {[%clk 15:07:54]} 20... g4 {[%clk 23:28:44]} 21. Nd4 {[%clk 5:40:21]} 21... Rhe8 {[%clk 16:54:13]} 22. Nab5 {[%clk 21:21:12]} 22... Be7 {[%clk 4:55:39]} 23. c4 {[%clk 3:19:55]} 23... Bh4+ {[%clk 18:15:54]} 24. Ke2 {[%clk 5:13:56]} 24... a6 {[%clk 7:55:44]} 25. Nc3 {[%clk 21:26:58]} 25... Ng3+ {[%clk 23:59:04]} 26. Kd1 {[%clk 15:26:24]} 26... Nf1 {[%clk 7:46:25]} 27. Nxd5 {[%clk 4:41:33]} 27... Nxh2 {[%clk 22:22:39]} 28. Rc1 {[%clk 2:10:20]} 28... Rg8 {[%clk 22:04:05]} 29. Nf6 {[%clk 9:48:49]} 29... Bxf6 {[%clk 14:05:17]} 0-1\n'

# %%
data[0].split('\n')
# Out:
# ['[Event "Live Chess"]',
#  '[Site "Chess.com"]',
#  '[Date "2021.04.01"]',
#  '[Round "-"]',
#  '[White "Hallsand"]',
#  '[Black "asad100000000"]',
#  '[Result "1-0"]',
#  '[CurrentPosition "1r1kR3/p5pp/2Qb1q2/2p5/3p4/1P1P3P/PBP2PB1/6K1 b - -"]',
#  '[Timezone "UTC"]',
#  '[ECO "A04"]',
#  '[ECOUrl "https://www.chess.com/openings/Reti-Opening-Black-Mustang-Defense"]',
#  '[UTCDate "2021.04.01"]',
#  '[UTCTime "21:59:46"]',
#  '[WhiteElo "701"]',
#  '[BlackElo "666"]',
#  '[TimeControl "300"]',
#  '[Termination "Hallsand won by checkmate"]',
#  '[StartTime "21:59:46"]',
#  '[EndDate "2021.04.01"]',
#  '[EndTime "22:07:13"]',
#  '[Link "https://www.chess.com/game/live/11053424045"]',
#  '',
#  '1. Nf3 {[%clk 0:05:00]} 1... Nc6 {[%clk 0:04:57.5]} 2. g3 {[%clk 0:04:52.7]} 2... Nf6 {[%clk 0:04:56.7]} 3. Bg2 {[%clk 0:04:50.2]} 3... e6 {[%clk 0:04:55.6]} 4. d3 {[%clk 0:04:48.9]} 4... d5 {[%clk 0:04:54.2]} 5. O-O {[%clk 0:04:47.8]} 5... e5 {[%clk 0:04:39.3]} 6. Nbd2 {[%clk 0:04:46.4]} 6... Bd6 {[%clk 0:04:26.8]} 7. e4 {[%clk 0:04:43.8]} 7... dxe4 {[%clk 0:04:21.6]} 8. Nxe4 {[%clk 0:04:33.2]} 8... Bg4 {[%clk 0:04:16]} 9. Qd2 {[%clk 0:04:23.2]} 9... Nd4 {[%clk 0:04:08]} 10. Nxd4 {[%clk 0:03:34.8]} 10... exd4 {[%clk 0:04:00.6]} 11. b3 {[%clk 0:03:28.3]} 11... Nxe4 {[%clk 0:03:46.1]} 12. Bxe4 {[%clk 0:03:25.8]} 12... f5 {[%clk 0:03:23.3]} 13. Bg2 {[%clk 0:03:22.2]} 13... c5 {[%clk 0:03:13.3]} 14. Re1+ {[%clk 0:03:20.5]} 14... Kd7 {[%clk 0:02:59]} 15. Bxb7 {[%clk 0:03:16.4]} 15... Rb8 {[%clk 0:02:55.2]} 16. Bg2 {[%clk 0:03:05.1]} 16... Qf6 {[%clk 0:02:33.6]} 17. h3 {[%clk 0:03:00.8]} 17... Bh5 {[%clk 0:02:28.9]} 18. Bb2 {[%clk 0:02:46.7]} 18... f4 {[%clk 0:02:18.8]} 19. gxf4 {[%clk 0:02:42.5]} 19... Bxf4 {[%clk 0:02:15]} 20. Qe2 {[%clk 0:02:36.4]} 20... Rhe8 {[%clk 0:02:06]} 21. Qxh5 {[%clk 0:02:32.1]} 21... Rxe1+ {[%clk 0:02:01.6]} 22. Rxe1 {[%clk 0:02:30.1]} 22... Bd2 {[%clk 0:01:52.1]} 23. Re2 {[%clk 0:02:20.9]} 23... Bf4 {[%clk 0:01:27.2]} 24. Qd5+ {[%clk 0:02:16.6]} 24... Bd6 {[%clk 0:01:23]} 25. Qc6+ {[%clk 0:02:10.9]} 25... Kd8 {[%clk 0:01:15.7]} 26. Qe8+ {[%clk 0:01:59.1]} 26... Kc7 {[%clk 0:01:09.5]} 27. Qc6+ {[%clk 0:01:48.2]} 27... Kd8 {[%clk 0:01:04.5]} 28. Re8# {[%clk 0:01:42.7]} 1-0',
#  '']

# %%
play.df
# Out:
#        player playerColor       opponent  result winningReason playerElo  \
# 0    Hallsand       Black   Danielhost19   Loser          time      1081
# 1    Hallsand       White     Osvaldo937   Loser          time      1081
# 2    Hallsand       Black   Danielhost19  Winner     checkmate      1081
# 3    Hallsand       Black     Osvaldo937  Winner          time      1081
# 4    Hallsand       White       ClimatBR  Winner   resignation      1119
# ..        ...         ...            ...     ...           ...       ...
# 139  Hallsand       White   the_big_josh  Winner     abandoned       654
# 140  Hallsand       Black       guiddiel  Winner   resignation       654
# 141  Hallsand       White          deve8  Winner          time       673
# 142  Hallsand       White  sai78666alpha   Loser   resignation       658
# 143  Hallsand       Black       iConqu3r   Loser   resignation       640
#
#     oponentElo timeControl        date      time               opening  pgn  \
# 0          800     1/86400  01/03/2020  15:27:42          Colle-System  1.
# 1         1000     1/86400  21/03/2020  14:34:25          Pirc-Defense  1.
# 2          800     1/86400  19/03/2020  10:29:07   Queens-Pawn-Opening  1.
# 3         1000     1/86400  24/03/2020  20:45:41    Kings-Pawn-Opening  1.
# 4          681     1/86400  14/03/2020  21:29:52    Kings-Pawn-Opening  1.
# ..         ...         ...         ...       ...                   ...  ...
# 139        792         300  25/09/2020  21:00:01  Scandinavian-Defense  1.
# 140        559         300  27/09/2020  12:15:21          Italian-Game  1.
# 141        620         300  28/09/2020  18:28:55        French-Defense  1.
# 142        762         300  28/09/2020  18:40:47      Philidor-Defense  1.
# 143        687         300  28/09/2020  18:42:19       Petrovs-Defense  1.
#
#              id
# 0     253102534
# 1     255393656
# 2     255102942
# 3     255870284
# 4     254576218
# ..          ...
# 139  5498086829
# 140  5505227594
# 141  5511225545
# 142  5511269543
# 143  5511275367
#
# [144 rows x 13 columns]

# %%
timeFormat = data[0]

# %%
data[0].split('\n')
# Out:
# ['[Event "Live Chess"]',
#  '[Site "Chess.com"]',
#  '[Date "2021.04.01"]',
#  '[Round "-"]',
#  '[White "Hallsand"]',
#  '[Black "asad100000000"]',
#  '[Result "1-0"]',
#  '[CurrentPosition "1r1kR3/p5pp/2Qb1q2/2p5/3p4/1P1P3P/PBP2PB1/6K1 b - -"]',
#  '[Timezone "UTC"]',
#  '[ECO "A04"]',
#  '[ECOUrl "https://www.chess.com/openings/Reti-Opening-Black-Mustang-Defense"]',
#  '[UTCDate "2021.04.01"]',
#  '[UTCTime "21:59:46"]',
#  '[WhiteElo "701"]',
#  '[BlackElo "666"]',
#  '[TimeControl "300"]',
#  '[Termination "Hallsand won by checkmate"]',
#  '[StartTime "21:59:46"]',
#  '[EndDate "2021.04.01"]',
#  '[EndTime "22:07:13"]',
#  '[Link "https://www.chess.com/game/live/11053424045"]',
#  '',
#  '1. Nf3 {[%clk 0:05:00]} 1... Nc6 {[%clk 0:04:57.5]} 2. g3 {[%clk 0:04:52.7]} 2... Nf6 {[%clk 0:04:56.7]} 3. Bg2 {[%clk 0:04:50.2]} 3... e6 {[%clk 0:04:55.6]} 4. d3 {[%clk 0:04:48.9]} 4... d5 {[%clk 0:04:54.2]} 5. O-O {[%clk 0:04:47.8]} 5... e5 {[%clk 0:04:39.3]} 6. Nbd2 {[%clk 0:04:46.4]} 6... Bd6 {[%clk 0:04:26.8]} 7. e4 {[%clk 0:04:43.8]} 7... dxe4 {[%clk 0:04:21.6]} 8. Nxe4 {[%clk 0:04:33.2]} 8... Bg4 {[%clk 0:04:16]} 9. Qd2 {[%clk 0:04:23.2]} 9... Nd4 {[%clk 0:04:08]} 10. Nxd4 {[%clk 0:03:34.8]} 10... exd4 {[%clk 0:04:00.6]} 11. b3 {[%clk 0:03:28.3]} 11... Nxe4 {[%clk 0:03:46.1]} 12. Bxe4 {[%clk 0:03:25.8]} 12... f5 {[%clk 0:03:23.3]} 13. Bg2 {[%clk 0:03:22.2]} 13... c5 {[%clk 0:03:13.3]} 14. Re1+ {[%clk 0:03:20.5]} 14... Kd7 {[%clk 0:02:59]} 15. Bxb7 {[%clk 0:03:16.4]} 15... Rb8 {[%clk 0:02:55.2]} 16. Bg2 {[%clk 0:03:05.1]} 16... Qf6 {[%clk 0:02:33.6]} 17. h3 {[%clk 0:03:00.8]} 17... Bh5 {[%clk 0:02:28.9]} 18. Bb2 {[%clk 0:02:46.7]} 18... f4 {[%clk 0:02:18.8]} 19. gxf4 {[%clk 0:02:42.5]} 19... Bxf4 {[%clk 0:02:15]} 20. Qe2 {[%clk 0:02:36.4]} 20... Rhe8 {[%clk 0:02:06]} 21. Qxh5 {[%clk 0:02:32.1]} 21... Rxe1+ {[%clk 0:02:01.6]} 22. Rxe1 {[%clk 0:02:30.1]} 22... Bd2 {[%clk 0:01:52.1]} 23. Re2 {[%clk 0:02:20.9]} 23... Bf4 {[%clk 0:01:27.2]} 24. Qd5+ {[%clk 0:02:16.6]} 24... Bd6 {[%clk 0:01:23]} 25. Qc6+ {[%clk 0:02:10.9]} 25... Kd8 {[%clk 0:01:15.7]} 26. Qe8+ {[%clk 0:01:59.1]} 26... Kc7 {[%clk 0:01:09.5]} 27. Qc6+ {[%clk 0:01:48.2]} 27... Kd8 {[%clk 0:01:04.5]} 28. Re8# {[%clk 0:01:42.7]} 1-0',
#  '']
